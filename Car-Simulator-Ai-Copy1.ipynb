# %% [markdown]
# # 1. Train the model

# %%
import gymnasium as gym  # Updated to gymnasium
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# Test Environment
environment_name = "CarRacing-v3"

# Create environment
env = gym.make(environment_name, render_mode="human")  # Add render_mode for compatibility

episodes = 5
for episode in range(1, episodes + 1):
    state, info = env.reset()  # Updated to include info in reset
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)  # Updated for gymnasium's step output
        done = terminated or truncated  # Combine termination conditions
        score += reward

    print(f"Episode: {episode} Score: {score}")

env.close()

# Example actions and observations
print(env.action_space.sample())
print(env.observation_space.sample())

# Train Model
log_path = os.path.join('Training', 'Logs')

# Ensure environment compatibility with Stable-Baselines3
env = gym.make(environment_name)

# Initialize the model with PPO and CNN policy
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)

# Set total timesteps to a higher value for longer training duration
total_timesteps = 1000000  # Adjust this for a 4-5 hour training duration

# Train the model for the specified number of timesteps
model.learn(total_timesteps=total_timesteps)

# Save Model after training
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model')
model.save(ppo_path)

# Evaluate and Test
evaluate_policy(model, env, n_eval_episodes=10, render=True)

env.close()

# Test the trained model
obs, info = env.reset()  
while True:
    action, _states = model.predict(obs)
    obs, rewards, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    env.render()

    if done:
        break

env.close()

# Save the model periodically during training (Optional)
# Example: Save the model every 10,000 timesteps
for i in range(0, total_timesteps, 10000):
    model.learn(total_timesteps=100000)
    model.save(f"{ppo_path}_checkpoint_{i}")
    print(f"Checkpoint saved at timestep {i}")
# Out:
# 2024-12-25 14:06:01.727094: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735153561.856225  325115 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735153561.887162  325115 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-25 14:06:02.202904: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Episode: 1 Score: -33.7748344370866
# Episode: 2 Score: -31.03448275862104
# Episode: 3 Score: -41.176470588235894
# Episode: 4 Score: -29.577464788732716
# Episode: 5 Score: -37.88819875776463
# [-0.25640416  0.4906586   0.87362874]
# [[[172 139  72]
#   [ 39  39 149]
#   [ 15 255  11]
#   ...
#   [245  86 208]
#   [ 70 148  20]
#   [156 181 165]]
#
#  [[ 61 208 110]
#   [229 117 184]
#   [165 199 193]
#   ...
#   [ 68  96 146]
#   [ 46 220 185]
#   [ 49  47   7]]
#
#  [[ 33 226 107]
#   [188  49 191]
#   [251 144  52]
#   ...
#   [179 125  34]
#   [ 64 241 197]
#   [189 185 236]]
#
#  ...
#
#  [[ 96   7  79]
#   [122  53 238]
#   [200 156 105]
#   ...
#   [ 68  17  62]
#   [185 102   7]
#   [230  92 127]]
#
#  [[216 132  91]
#   [225  85 247]
#   [ 95 231 238]
#   ...
#   [148 138  10]
#   [109  58  45]
#   [238 160 238]]
#
#  [[ 18 117 219]
#   [199  31 113]
#   [ 72 146  82]
#   ...
#   [227  56 235]
#   [ 38 176 144]
#   [ 93 252   5]]]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# [W1225 14:09:45.900482698 NNPACK.cpp:61] Could not initialize NNPACK! Reason: Unsupported hardware.
# Logging to Training/Logs/PPO_7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -52.1    |
# | time/              |          |
# |    fps             | 79       |
# |    iterations      | 1        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.6       |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 2           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005525681 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.00273     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.182       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00438    |
# |    std                  | 0.99        |
# |    value_loss           | 0.618       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 3           |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010195458 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.0156      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.285       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00811    |
# |    std                  | 0.977       |
# |    value_loss           | 0.712       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.8       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 4           |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009111976 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.0454      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.22        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.964       |
# |    value_loss           | 0.578       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.2       |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 5           |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014171062 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | -0.0274     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0567      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.952       |
# |    value_loss           | 0.348       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -53.2        |
# | time/                   |              |
# |    fps                  | 45           |
# |    iterations           | 6            |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0113759935 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.08        |
# |    explained_variance   | 0.343        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0104      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0194      |
# |    std                  | 0.937        |
# |    value_loss           | 0.222        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.7       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 7           |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016102215 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0593      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.929       |
# |    value_loss           | 0.215       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.5       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 8           |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013381282 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.09        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.918       |
# |    value_loss           | 0.374       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 9           |
# |    time_elapsed         | 416         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012980925 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0747      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.916       |
# |    value_loss           | 0.252       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.7       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 10          |
# |    time_elapsed         | 463         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017033331 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0641      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0238     |
# |    std                  | 0.911       |
# |    value_loss           | 0.386       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.3       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 11          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015598198 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0679      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0218     |
# |    std                  | 0.913       |
# |    value_loss           | 0.344       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43         |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 12          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022445139 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0255     |
# |    std                  | 0.905       |
# |    value_loss           | 0.288       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -37.3       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 13          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.020868352 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0824      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0224     |
# |    std                  | 0.894       |
# |    value_loss           | 0.493       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -35.2       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 14          |
# |    time_elapsed         | 646         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.022290945 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.24        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.222       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0306     |
# |    std                  | 0.882       |
# |    value_loss           | 0.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -34.1       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 15          |
# |    time_elapsed         | 695         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.025385346 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0266      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0322     |
# |    std                  | 0.871       |
# |    value_loss           | 0.329       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -33.5       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 16          |
# |    time_elapsed         | 738         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.025578571 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00807     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0295     |
# |    std                  | 0.853       |
# |    value_loss           | 0.331       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -31.5     |
# | time/                   |           |
# |    fps                  | 44        |
# |    iterations           | 17        |
# |    time_elapsed         | 782       |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0357117 |
# |    clip_fraction        | 0.273     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.75     |
# |    explained_variance   | 0.773     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0293    |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -0.0296   |
# |    std                  | 0.839     |
# |    value_loss           | 0.276     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -26.5       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 18          |
# |    time_elapsed         | 826         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.025828686 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.113       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.829       |
# |    value_loss           | 0.433       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -25.8       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 19          |
# |    time_elapsed         | 870         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.028701574 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0731      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0344     |
# |    std                  | 0.817       |
# |    value_loss           | 0.621       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -21.9       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 20          |
# |    time_elapsed         | 913         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.036224492 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.017       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0333     |
# |    std                  | 0.805       |
# |    value_loss           | 0.289       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -13.4       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 21          |
# |    time_elapsed         | 957         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.036244996 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.228       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.797       |
# |    value_loss           | 0.983       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 0.109       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 22          |
# |    time_elapsed         | 1002        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.041722335 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.19        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.029      |
# |    std                  | 0.792       |
# |    value_loss           | 0.794       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 14.2       |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 23         |
# |    time_elapsed         | 1049       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.03521985 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.54      |
# |    explained_variance   | 0.736      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.474      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0261    |
# |    std                  | 0.787      |
# |    value_loss           | 2.25       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 22.8        |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 24          |
# |    time_elapsed         | 1107        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.031779855 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.0197      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.395       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0187     |
# |    std                  | 0.784       |
# |    value_loss           | 2.63        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 25.4       |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 25         |
# |    time_elapsed         | 1155       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.04213973 |
# |    clip_fraction        | 0.33       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | 0.777      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.42       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0163    |
# |    std                  | 0.779      |
# |    value_loss           | 1.93       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 39         |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 26         |
# |    time_elapsed         | 1203       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.04100693 |
# |    clip_fraction        | 0.347      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.48      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.209      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0114    |
# |    std                  | 0.773      |
# |    value_loss           | 1.32       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 47.7       |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 27         |
# |    time_elapsed         | 1250       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.03838586 |
# |    clip_fraction        | 0.342      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.46      |
# |    explained_variance   | 0.877      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.411      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0172    |
# |    std                  | 0.769      |
# |    value_loss           | 3.53       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 54.5       |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 28         |
# |    time_elapsed         | 1297       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.03946121 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.45      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.418      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00421   |
# |    std                  | 0.765      |
# |    value_loss           | 2.06       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 65.7       |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 29         |
# |    time_elapsed         | 1343       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.03920635 |
# |    clip_fraction        | 0.353      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.43      |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.926      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0104    |
# |    std                  | 0.761      |
# |    value_loss           | 3.05       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 75.1       |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 30         |
# |    time_elapsed         | 1401       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.03816599 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.42      |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.743      |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00861   |
# |    std                  | 0.758      |
# |    value_loss           | 3.51       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 84          |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 31          |
# |    time_elapsed         | 1451        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.042621046 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.837       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.754       |
# |    value_loss           | 5.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 97.6        |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 32          |
# |    time_elapsed         | 1499        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.041174088 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00314    |
# |    std                  | 0.753       |
# |    value_loss           | 8.14        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 110        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 33         |
# |    time_elapsed         | 1546       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.04055389 |
# |    clip_fraction        | 0.351      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.38      |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.91       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00717   |
# |    std                  | 0.749      |
# |    value_loss           | 10.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 114        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 34         |
# |    time_elapsed         | 1592       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.06046699 |
# |    clip_fraction        | 0.418      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.35       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.000462   |
# |    std                  | 0.746      |
# |    value_loss           | 9.64       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 118         |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 35          |
# |    time_elapsed         | 1637        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.065445125 |
# |    clip_fraction        | 0.415       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00691     |
# |    std                  | 0.747       |
# |    value_loss           | 5.97        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 136        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 36         |
# |    time_elapsed         | 1683       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.05526449 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.481      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00162   |
# |    std                  | 0.741      |
# |    value_loss           | 3.9        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 37          |
# |    time_elapsed         | 1730        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.072708845 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.93        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0129      |
# |    std                  | 0.741       |
# |    value_loss           | 10.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 38          |
# |    time_elapsed         | 1776        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.055148363 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00707     |
# |    std                  | 0.743       |
# |    value_loss           | 8.78        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 170        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 39         |
# |    time_elapsed         | 1823       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.07631412 |
# |    clip_fraction        | 0.466      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.75       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.00239    |
# |    std                  | 0.743      |
# |    value_loss           | 6.67       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 183        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 40         |
# |    time_elapsed         | 1869       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.06790426 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.34      |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.892      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00686    |
# |    std                  | 0.741      |
# |    value_loss           | 9.36       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 191        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 41         |
# |    time_elapsed         | 1915       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.08282147 |
# |    clip_fraction        | 0.486      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.34      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.02       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00958    |
# |    std                  | 0.742      |
# |    value_loss           | 10.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 42         |
# |    time_elapsed         | 1962       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.08840234 |
# |    clip_fraction        | 0.482      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.34      |
# |    explained_variance   | 0.665      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.3        |
# |    n_updates            | 410        |
# |    policy_gradient_loss | 0.0216     |
# |    std                  | 0.741      |
# |    value_loss           | 14.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 43         |
# |    time_elapsed         | 2012       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.08154209 |
# |    clip_fraction        | 0.446      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.34      |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.81       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.00299    |
# |    std                  | 0.744      |
# |    value_loss           | 11.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 223        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 44         |
# |    time_elapsed         | 2064       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.18491635 |
# |    clip_fraction        | 0.514      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.33      |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.77       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.0161     |
# |    std                  | 0.738      |
# |    value_loss           | 9.01       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 236       |
# | time/                   |           |
# |    fps                  | 43        |
# |    iterations           | 45        |
# |    time_elapsed         | 2111      |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0790339 |
# |    clip_fraction        | 0.448     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.32     |
# |    explained_variance   | 0.932     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.98      |
# |    n_updates            | 440       |
# |    policy_gradient_loss | 0.0148    |
# |    std                  | 0.739     |
# |    value_loss           | 10.6      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 46          |
# |    time_elapsed         | 2157        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.067237675 |
# |    clip_fraction        | 0.47        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.33       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.46        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.024       |
# |    std                  | 0.743       |
# |    value_loss           | 20          |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 256       |
# | time/                   |           |
# |    fps                  | 43        |
# |    iterations           | 47        |
# |    time_elapsed         | 2203      |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.0661167 |
# |    clip_fraction        | 0.511     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.35     |
# |    explained_variance   | 0.873     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.973     |
# |    n_updates            | 460       |
# |    policy_gradient_loss | 0.0234    |
# |    std                  | 0.747     |
# |    value_loss           | 7.24      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 999         |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 48          |
# |    time_elapsed         | 2249        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.089749835 |
# |    clip_fraction        | 0.518       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.2         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.019       |
# |    std                  | 0.748       |
# |    value_loss           | 7.7         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 998        |
# |    ep_rew_mean          | 278        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 49         |
# |    time_elapsed         | 2294       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.13202085 |
# |    clip_fraction        | 0.496      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.36      |
# |    explained_variance   | 0.584      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.79       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.025      |
# |    std                  | 0.746      |
# |    value_loss           | 23.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 998        |
# |    ep_rew_mean          | 297        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 50         |
# |    time_elapsed         | 2340       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.07988033 |
# |    clip_fraction        | 0.474      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.822      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.93       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.0108     |
# |    std                  | 0.746      |
# |    value_loss           | 19.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 998        |
# |    ep_rew_mean          | 311        |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 51         |
# |    time_elapsed         | 2386       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.07832208 |
# |    clip_fraction        | 0.462      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.69       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | 0.004      |
# ...
# |    ep_rew_mean          | 559        |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 45         |
# |    time_elapsed         | 2067       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.09705992 |
# |    clip_fraction        | 0.475      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.72      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.14       |
# |    n_updates            | 9250       |
# |    policy_gradient_loss | 0.00077    |
# |    std                  | 1.66       |
# |    value_loss           | 10         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 974         |
# |    ep_rew_mean          | 560         |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 46          |
# |    time_elapsed         | 2118        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.059235964 |
# |    clip_fraction        | 0.429       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.466       |
# |    n_updates            | 9260        |
# |    policy_gradient_loss | 0.0004      |
# |    std                  | 1.66        |
# |    value_loss           | 6.97        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 975        |
# |    ep_rew_mean          | 556        |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 47         |
# |    time_elapsed         | 2165       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.05446268 |
# |    clip_fraction        | 0.447      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.72      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.464      |
# |    n_updates            | 9270       |
# |    policy_gradient_loss | 0.00136    |
# |    std                  | 1.66       |
# |    value_loss           | 4.88       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 975         |
# |    ep_rew_mean          | 554         |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 48          |
# |    time_elapsed         | 2215        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.072902635 |
# |    clip_fraction        | 0.465       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.354       |
# |    n_updates            | 9280        |
# |    policy_gradient_loss | -0.00145    |
# |    std                  | 1.68        |
# |    value_loss           | 5.19        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 975       |
# |    ep_rew_mean          | 557       |
# | time/                   |           |
# |    fps                  | 44        |
# |    iterations           | 49        |
# |    time_elapsed         | 2267      |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.0825838 |
# |    clip_fraction        | 0.495     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.76     |
# |    explained_variance   | 0.912     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.783     |
# |    n_updates            | 9290      |
# |    policy_gradient_loss | 0.00281   |
# |    std                  | 1.68      |
# |    value_loss           | 9.48      |
# ---------------------------------------
# Checkpoint saved at timestep 80000
# Logging to Training/Logs/PPO_17
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 503      |
# | time/              |          |
# |    fps             | 85       |
# |    iterations      | 1        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 930        |
# |    ep_rew_mean          | 374        |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 2          |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.06125379 |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.76      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.701      |
# |    n_updates            | 9310       |
# |    policy_gradient_loss | 0.00733    |
# |    std                  | 1.68       |
# |    value_loss           | 7.18       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 954        |
# |    ep_rew_mean          | 300        |
# | time/                   |            |
# |    fps                  | 51         |
# |    iterations           | 3          |
# |    time_elapsed         | 118        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.12941425 |
# |    clip_fraction        | 0.479      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.75      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.87       |
# |    n_updates            | 9320       |
# |    policy_gradient_loss | 0.0138     |
# |    std                  | 1.68       |
# |    value_loss           | 7.45       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 931        |
# |    ep_rew_mean          | 346        |
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 4          |
# |    time_elapsed         | 169        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.14820552 |
# |    clip_fraction        | 0.41       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.74      |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.311      |
# |    n_updates            | 9330       |
# |    policy_gradient_loss | -0.00947   |
# |    std                  | 1.67       |
# |    value_loss           | 5.95       |
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 74
#      71 # Save the model periodically during training (Optional)
#      72 # Example: Save the model every 10,000 timesteps
#      73 for i in range(0, total_timesteps, 10000):
# ---> 74     model.learn(total_timesteps=100000)
#      75     model.save(f"{ppo_path}_checkpoint_{i}")
#      76     print(f"Checkpoint saved at timestep {i}")
#
# File ~/myenv/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/myenv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File ~/myenv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/myenv/lib/python3.12/site-packages/stable_baselines3/common/policies.py:645, in ActorCriticPolicy.forward(self, obs, deterministic)
#     637 """
#     638 Forward pass in all the networks (actor and critic)
#     639
#    (...)
#     642 :return: action, value and log probability of the action
#     643 """
#     644 # Preprocess the observation if needed
# --> 645 features = self.extract_features(obs)
#     646 if self.share_features_extractor:
#     647     latent_pi, latent_vf = self.mlp_extractor(features)
#
# File ~/myenv/lib/python3.12/site-packages/stable_baselines3/common/policies.py:672, in ActorCriticPolicy.extract_features(self, obs, features_extractor)
#     663 """
#     664 Preprocess the observation if needed and extract features.
#     665
#    (...)
#     669     features for the actor and the features for the critic.
#     670 """
#     671 if self.share_features_extractor:
# --> 672     return super().extract_features(obs, self.features_extractor if features_extractor is None else features_extractor)
#     673 else:
#     674     if features_extractor is not None:
#
# File ~/myenv/lib/python3.12/site-packages/stable_baselines3/common/policies.py:131, in BaseModel.extract_features(self, obs, features_extractor)
#     123 """
#     124 Preprocess the observation if needed and extract features.
#     125
#    (...)
#     128 :return: The extracted features
#     129 """
#     130 preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 131 return features_extractor(preprocessed_obs)
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/myenv/lib/python3.12/site-packages/stable_baselines3/common/torch_layers.py:107, in NatureCNN.forward(self, observations)
#     106 def forward(self, observations: th.Tensor) -> th.Tensor:
# --> 107     return self.linear(self.cnn(observations))
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/myenv/lib/python3.12/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %%
# 2. Test the model

# %%
from stable_baselines3 import PPO
import gymnasium as gym
import os

# Define the environment name
environment_name = "CarRacing-v3"

# Create the environment
env = gym.make(environment_name, render_mode="human")  # Add render_mode for visualization

# Specify the path to the saved model
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model.zip')

# Load the saved model
model = PPO.load(ppo_path)

# Test the model
obs, info = env.reset()  # Reset the environment
while True:
    # Use the model to predict actions
    action, _states = model.predict(obs)
    obs, rewards, terminated, truncated, info = env.step(action)  # Step through the environment
    done = terminated or truncated
    env.render()  # Render the environment

    if done:
        break  # Exit the loop if the episode ends

env.close()  # Close the environment
